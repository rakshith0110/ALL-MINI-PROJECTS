# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(color_codes=True)

# %%
df=pd.read_csv('Rainfall.csv')
df
# Out:
#      day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   \
# 0      1     1025.9     19.9         18.3     16.8      13.1         72
# 1      2     1022.0     21.7         18.9     17.2      15.6         81
# 2      3     1019.7     20.3         19.3     18.0      18.4         95
# 3      4     1018.9     22.3         20.6     19.1      18.8         90
# 4      5     1015.9     21.3         20.7     20.2      19.9         95
# ..   ...        ...      ...          ...      ...       ...        ...
# 361   27     1022.7     18.8         17.7     16.9      15.0         84
# 362   28     1026.6     18.6         17.3     16.3      12.8         75
# 363   29     1025.9     18.9         17.7     16.4      13.3         75
# 364   30     1025.3     19.2         17.3     15.2      13.3         78
# 365   31     1026.4     20.5         17.8     15.5      13.0         74
#
#      cloud  rainfall  sunshine           winddirection  windspeed
# 0        49      yes       9.3                    80.0       26.3
# 1        83      yes       0.6                    50.0       15.3
# 2        91      yes       0.0                    40.0       14.2
# 3        88      yes       1.0                    50.0       16.9
# 4        81      yes       0.0                    40.0       13.7
# ..      ...      ...       ...                     ...        ...
# 361      90      yes       0.0                    30.0       18.4
# 362      85      yes       1.0                    20.0       25.9
# 363      78      yes       4.6                    70.0       33.4
# 364      86      yes       1.2                    20.0       20.9
# 365      66       no       5.7                    20.0       23.3
#
# [366 rows x 12 columns]

# %%
df.shape
# Out:
# (366, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   day                     366 non-null    int64
#  1   pressure                366 non-null    float64
#  2   maxtemp                 366 non-null    float64
#  3   temparature             366 non-null    float64
#  4   mintemp                 366 non-null    float64
#  5   dewpoint                366 non-null    float64
#  6   humidity                366 non-null    int64
#  7   cloud                   366 non-null    int64
#  8   rainfall                366 non-null    object
#  9   sunshine                366 non-null    float64
#  10           winddirection  365 non-null    float64
#  11  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
df.rename(str.strip,axis='columns',inplace=True)
df.columns
# Out:
# Index(['day', 'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
#        'humidity', 'cloud', 'rainfall', 'sunshine', 'winddirection',
#        'windspeed'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# rainfall         0
# sunshine         0
# winddirection    1
# windspeed        1
# dtype: int64

# %%
sns.boxplot(x=df['winddirection'])
# Out:
# <Axes: xlabel='winddirection'>

# %%
df['winddirection'].fillna(df['winddirection'].mean(), inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11752\1007283737.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['winddirection'].fillna(df['winddirection'].mean(), inplace=True)

# %%
sns.boxplot(x=df['windspeed'])
# Out:
# <Axes: xlabel='windspeed'>

# %%
df['windspeed'].fillna(df['windspeed'].mean(), inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11752\3492531869.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['windspeed'].fillna(df['windspeed'].mean(), inplace=True)

# %%
df['rainfall'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
#Change value in rainfall column
df['rainfall'] = df['rainfall'].replace(['no'],'0')
df['rainfall'] = df['rainfall'].replace(['yes'],'1')
df['rainfall'] = pd.to_numeric(df['rainfall'])

# %%
df.columns = df.columns.str.strip()

# %%
df
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0      1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1      2    1022.0     21.7         18.9     17.2      15.6        81     83
# 2      3    1019.7     20.3         19.3     18.0      18.4        95     91
# 3      4    1018.9     22.3         20.6     19.1      18.8        90     88
# 4      5    1015.9     21.3         20.7     20.2      19.9        95     81
# ..   ...       ...      ...          ...      ...       ...       ...    ...
# 361   27    1022.7     18.8         17.7     16.9      15.0        84     90
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
#      rainfall  sunshine  winddirection  windspeed
# 0           1       9.3           80.0       26.3
# 1           1       0.6           50.0       15.3
# 2           1       0.0           40.0       14.2
# 3           1       1.0           50.0       16.9
# 4           1       0.0           40.0       13.7
# ..        ...       ...            ...        ...
# 361         1       0.0           30.0       18.4
# 362         1       1.0           20.0       25.9
# 363         1       4.6           70.0       33.4
# 364         1       1.2           20.0       20.9
# 365         0       5.7           20.0       23.3
#
# [366 rows x 12 columns]

# %%
sns.countplot(x=df['rainfall'])
print(df.rainfall.value_counts())
# Out:
# rainfall
# 1    249
# 0    117
# Name: count, dtype: int64

# %%
import scipy.stats as stats
z = np.abs(stats.zscore(df))
dfo = df[(z<3).all(axis = 1)] 
dfo.shape
# Out:
# (355, 12)

# %%
from imblearn.over_sampling import SMOTE
X = dfo.drop('rainfall', axis=1)
y = dfo['rainfall']
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)
df_resampled = pd.concat([X_resampled, pd.Series(y_resampled, name='rainfall')], axis=1)

# %%
sns.countplot(x=df_resampled['rainfall'])
print(df_resampled.rainfall.value_counts())
# Out:
# rainfall
# 1    246
# 0    246
# Name: count, dtype: int64

# %%
corr_matrix = dfo.corr(numeric_only=True)
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
dfo.groupby('rainfall').mean()
# Out:
#                 day     pressure    maxtemp  temparature    mintemp  \
# rainfall
# 0         15.688073  1013.954128  27.698165    24.701835  22.650459
# 1         15.808943  1013.215041  25.900407    23.727642  21.992276
#
#            dewpoint   humidity      cloud  sunshine  winddirection  windspeed
# rainfall
# 0         19.754128  74.816514  53.577982  7.443119     105.871560  18.552294
# 1         20.695122  83.699187  80.313008  2.960569     101.591491  22.193240

# %%
sns.boxplot(x='rainfall', y='windspeed', data=df)
plt.title('Windspeed vs Rainfall')
plt.show()

# %%
X = dfo.drop('rainfall', 'day', axis=1)
y = dfo['rainfall']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,confusion_matrix

# %%
def model_fit(model):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    model_acc =round(accuracy_score(y_pred,y_test)*100,2)
    print(f"Acurracy Score : {model_acc}%")
    print("")
    sns.heatmap(confusion_matrix(y_pred,y_test),annot=True,square=True,cmap='Blues')
    plt.xlabel("actual label")
    plt.ylabel("predicted label")
    plt.title(f"CONFUSION MATRIX")
    print("")

# %%
#Logistic Regression(LR)
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000, random_state=0)
model_fit(lr)
# Out:
# Acurracy Score : 84.51%

# %%
#Support Vector Machine(SVC)
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0)
model_fit(svm)
# Out:
# Acurracy Score : 63.38%

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
model_fit(knn)
# Out:
# Acurracy Score : 78.87%

# %%
#XGBoost
from xgboost import XGBClassifier
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=0)
model_fit(xgb)
# Out:
# C:\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:08:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Acurracy Score : 77.46%

# %%
#AdaBoost
from sklearn.ensemble import AdaBoostClassifier
ab = AdaBoostClassifier(random_state=0)
model_fit(ab)
# Out:
# Acurracy Score : 85.92%

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=0)
model_fit(rf)
# Out:
# Acurracy Score : 80.28%

# %%
#input
sample1 = pd.DataFrame([{
    'pressure': 1012.5,
    'maxtemp': 25.0,
    'temparature': 22.5,
    'mintemp': 20.0,
    'dewpoint': 18.0,
    'humidity': 85,
    'cloud': 75,
    'sunshine': 2.0,
    'winddirection': 60.0,
    'windspeed': 15.0
}])
sample1 = sample1[X.columns]

# %%
from IPython.display import display, HTML
# Predict
prediction = rf.predict(sample1)[0]
if prediction == 1:
    html = '<h1 style="color:white; background-color:green; padding:20px; text-align:center;">Rainfall Prediction: YES</h1>'
else:
    html = '<h1 style="color:white; background-color:red; padding:20px; text-align:center;">Rainfall Prediction: NO</h1>'

display(HTML(html))
# Out:
# <h1 style="color:white; background-color:green; padding:20px; text-align:center;">Rainfall Prediction: YES</h1>

# %%
sample2 = pd.DataFrame([{
    'pressure': 1015.0,
    'maxtemp': 32.0,
    'temparature': 28.0,
    'mintemp': 24.0,
    'dewpoint': 18.0,
    'humidity': 55,
    'cloud': 20,
    'sunshine': 8.0,
    'winddirection': 90.0,
    'windspeed': 10.0
}])

# %%
from IPython.display import display, HTML

# Predict
prediction = rf.predict(sample2)[0]

if prediction == 1:
    html = '<h1 style="color:white; background-color:green; padding:20px; text-align:center;">Rainfall Prediction: YES</h1>'
else:
    html = '<h1 style="color:white; background-color:red; padding:20px; text-align:center;">Rainfall Prediction: NO</h1>'

display(HTML(html))
# Out:
# <h1 style="color:white; background-color:red; padding:20px; text-align:center;">Rainfall Prediction: NO</h1>

# %%
sample3 = pd.DataFrame([{
    'pressure': 1005.0,
    'maxtemp': 24.0,
    'temparature': 22.0,
    'mintemp': 20.0,
    'dewpoint': 19.0,
    'humidity': 92,
    'cloud': 90,
    'sunshine': 1.5,
    'winddirection': 150.0,
    'windspeed': 5.0
}])

# %%
from IPython.display import display, HTML

# Predict
prediction = rf.predict(sample3)[0]

if prediction == 1:
    html = '<h1 style="color:white; background-color:green; padding:20px; text-align:center;">Rainfall Prediction: YES</h1>'
else:
    html = '<h1 style="color:white; background-color:red; padding:20px; text-align:center;">Rainfall Prediction: NO</h1>'

display(HTML(html))
# Out:
# <h1 style="color:white; background-color:green; padding:20px; text-align:center;">Rainfall Prediction: YES</h1>
